# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Preeti Sarin**
# Data Analyst

# %% [markdown]
# _I am interested in data science because it helps to convert data into meaningful information, which can be used by the companies to enhance their product, services or experinece._

# %% [markdown]
# ### In next cell I am performing basic mathematical calculation as addition of two numbers (example: 23+67)

# %%
23+67
# Out:
# 90

# %% [markdown]
# ### <center>Welcome to Jupyter Notebook coding</center>
# ***
# |Sr No|Name of HTML tag used|Example|
# |:---:|:---|---|
# |1|Strike Through|~~strickthrough~~|
# |2|Hyperlink|[By clicking this you wil be redirected to google homepage](http://www.google.com)|
# |3|Image|![alt txt](https://upload.wikimedia.org/wikipedia/commons/3/38/Jupyter_logo.svg)|
#
# **Bulleted List and Numbered List**
# - Item 1
#     1. sub item 11
#     1. sub item 12
# - Item 2
# - Item 3
# >Code or syntax
# ```python
#               x="welcome to Python Programming"
#               print(x)```
